# %%
# Sentiment API Test Example

import requests
import random
from concurrent.futures import ThreadPoolExecutor, as_completed

# Your Azure Container App endpoint
ENDPOINT = "https://sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io/predict"

# %%
payload = {
    "text": "This is absolutely fantastic! I love it."
}

response = requests.post(ENDPOINT, json=payload)
print("Status code:", response.status_code)
print("Response JSON:", response.json())
# Out:
# Status code: 200
# Response JSON: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 34.66257699983544}

# %%
#function to send one request
def send_request(text):
    payload = {"text": text}
    try:
        response = requests.post(ENDPOINT, json=payload, timeout=10)
        return {
            "text": text,
            "status_code": response.status_code,
            "response": response.json() if response.status_code == 200 else response.text
        }
    except Exception as e:
        return {
            "text": text,
            "status_code": "ERROR",
            "response": str(e)
        }

# %%
texts = [
    "This is absolutely fantastic! I love it.",
    "What a terrible experience. I am very disappointed.",
    "It's okay, nothing special but not bad.",
    "I can't believe how easy this was to use!",
    "The service was slow and unhelpful.",
    "Amazing product. Will buy again!",
    "Worst purchase I've ever made.",
    "Mediocre at best.",
    "Super fast delivery, thank you!",
    "Not what I expected, but acceptable."
]

n_requests = 100

#Send requests in parallel
results = []
with ThreadPoolExecutor(max_workers=n_requests) as executor:
    futures = [executor.submit(send_request, random.choice(texts)) for _ in range(n_requests)]
    for future in as_completed(futures):
        results.append(future.result())

# %%
# Display results
for r in results:
    print("Text:", r["text"])
    print("Status code:", r["status_code"])
    print("API response:", r["response"])
    print("-" * 50)
# Out:
# Text: Worst purchase I've ever made.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997829794883728, 'latency_ms': 57.45348699929309}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 103.63507000147365}
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.999749481678009, 'latency_ms': 185.5347980017541}
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9982989430427551, 'latency_ms': 106.53817499769502}
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.999749481678009, 'latency_ms': 103.70496000177809}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 104.94730700156651}
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9948359727859497, 'latency_ms': 189.2968229985854}
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997829794883728, 'latency_ms': 103.04878000169992}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 105.30206299881684}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 102.78018600001815}
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9948359727859497, 'latency_ms': 112.05391399926157}
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.999749481678009, 'latency_ms': 104.86344099990674}
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997829794883728, 'latency_ms': 185.7366859985632}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 114.36514299930423}
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997829794883728, 'latency_ms': 189.88241300030495}
# --------------------------------------------------
# Text: Amazing product. Will buy again!
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998774528503418, 'latency_ms': 109.79884499829495}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 107.6826299977256}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 103.05340900231386}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 103.41242799768224}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 103.56734699962544}
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997829794883728, 'latency_ms': 183.89934500009986}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 104.59948800053098}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 100.91171100066276}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 186.08699399919715}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 107.49667799973395}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 101.2360249987978}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 102.79886100033764}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 182.68938300025184}
# --------------------------------------------------
# Text: Super fast delivery, thank you!
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998496770858765, 'latency_ms': 102.03069400085951}
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9982989430427551, 'latency_ms': 104.49091400005273}
# --------------------------------------------------
# Text: Amazing product. Will buy again!
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998774528503418, 'latency_ms': 106.76071899797535}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 181.86187500032247}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 108.87606299729669}
# --------------------------------------------------
# Text: Super fast delivery, thank you!
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998496770858765, 'latency_ms': 106.66631999993115}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 182.3089949975838}
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9948359727859497, 'latency_ms': 103.78420199776883}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 108.28287299955264}
# --------------------------------------------------
# Text: Amazing product. Will buy again!
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998774528503418, 'latency_ms': 186.42116200135206}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 107.53652000130387}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 184.0372139995452}
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9982989430427551, 'latency_ms': 106.30212199976086}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 104.87741000179085}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 194.63861199983512}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 191.55958100236603}
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997829794883728, 'latency_ms': 103.92314899945632}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 108.48004699801095}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 103.38846300146542}
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9982989430427551, 'latency_ms': 179.4688469999528}
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9948359727859497, 'latency_ms': 102.51589099789271}
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9948359727859497, 'latency_ms': 103.26933999749599}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 100.10833900014404}
# --------------------------------------------------
# Text: Amazing product. Will buy again!
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998774528503418, 'latency_ms': 106.39695899953949}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 180.56635699758772}
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9982989430427551, 'latency_ms': 112.24940200190758}
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9948359727859497, 'latency_ms': 183.99544099884224}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 104.35021500234143}
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.999749481678009, 'latency_ms': 104.98279500097851}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 108.10827999739558}
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9998773336410522, 'latency_ms': 181.13759699917864}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 102.44985800090944}
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997829794883728, 'latency_ms': 110.94206500274595}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 195.70795300023747}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 184.37536000055843}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 114.96535100013716}
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9982989430427551, 'latency_ms': 189.4326129986439}
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.999749481678009, 'latency_ms': 104.05477299718768}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 183.70214400056284}
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: 200
# API response: {'label': 'POSITIVE', 'score': 0.9982989430427551, 'latency_ms': 105.08165099963662}
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.999749481678009, 'latency_ms': 106.22307700032252}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 101.90562800198677}
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997559189796448, 'latency_ms': 181.41523599842913}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 109.40692200165358}
# --------------------------------------------------
# Text: The service was slow and unhelpful.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9993890523910522, 'latency_ms': 103.0271840027126}
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9997829794883728, 'latency_ms': 107.32156399899395}
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.999749481678009, 'latency_ms': 105.17123600220657}
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: 200
# API response: {'label': 'NEGATIVE', 'score': 0.9992144107818604, 'latency_ms': 108.19345999698271}
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: I can't believe how easy this was to use!
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Super fast delivery, thank you!
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: What a terrible experience. I am very disappointed.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Mediocre at best.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Super fast delivery, thank you!
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Amazing product. Will buy again!
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Not what I expected, but acceptable.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: This is absolutely fantastic! I love it.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: Worst purchase I've ever made.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
# Text: It's okay, nothing special but not bad.
# Status code: ERROR
# API response: HTTPSConnectionPool(host='sentiment-api-stage.ashybush-155fc5f4.westus2.azurecontainerapps.io', port=443): Read timed out. (read timeout=10)
# --------------------------------------------------
